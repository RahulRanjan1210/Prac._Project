# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('happiness_score_dataset.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.isnull()
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      False   False           False            False           False
# 1      False   False           False            False           False
# 2      False   False           False            False           False
# 3      False   False           False            False           False
# 4      False   False           False            False           False
# ..       ...     ...             ...              ...             ...
# 153    False   False           False            False           False
# 154    False   False           False            False           False
# 155    False   False           False            False           False
# 156    False   False           False            False           False
# 157    False   False           False            False           False
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# ### EDA
# ### Scatterplot:

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Happiness Score',y='Country',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Country'>

# %%
sns.scatterplot(x='Happiness Score',y='Region',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Region'>

# %%
sns.scatterplot(x='Happiness Rank',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Happiness Score',y='Standard Error',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Standard Error'>

# %%
sns.scatterplot(x='Happiness Score',y='Economy (GDP per Capita)',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Economy (GDP per Capita)'>

# %%
sns.scatterplot(x='Happiness Score',y='Family',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Family'>

# %%
sns.scatterplot(x='Happiness Score',y='Health (Life Expectancy)',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Health (Life Expectancy)'>

# %%
sns.scatterplot(x='Happiness Score',y='Freedom',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Freedom'>

# %%
sns.scatterplot(x='Happiness Score',y='Trust (Government Corruption)',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Trust (Government Corruption)'>

# %%
sns.scatterplot(x='Happiness Score',y='Generosity',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Generosity'>

# %%
sns.scatterplot(x='Happiness Score',y='Dystopia Residual',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Dystopia Residual'>

# %%
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.savefig('pairplot.png')
plt.show()

# %% [markdown]
# ### Correlation:

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
type(df.corr())
# Out:
# pandas.core.frame.DataFrame

# %% [raw]
# df.corr()['Outcome'].sort_values()

# %% [markdown]
# ### Correlation using heatmap:

# %%
import matplotlib.pyplot as plt
# size of canvas
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Outcome of Correlation:

# %% [raw]
# All the columns of the dataset is positively correlated with the target column.
#
#
# 1. Happiness Rank has 52 percent correlation with the target column which can be consideted as a Strong  bond.
# 2. Happiness score has 53 percent correlation with the target column which can be considered as a strong bond.
# 3. Standerd Error has 8 percent correlation with the target column which can be considered as a weak bond.
# 4. Economy has 4 percent correlation with the target column which can be considered as a weak bond.
# 5. Family has 15 percent correlation with the target column which can be considered as a good bond.
# 6. Health has 2 percent correlation with the target column which can be considered as a weak bond.
# 7. Freedom has 6 percent correlation with the target column which can be considered as a weak bond.
# 8. Trust has 3 percent correlation with the target column which can be considered as a weak bond.
# 9. Generosity has 10 percent correlation with the target column which can be comsidered as weak bond.
#
#
# Max correlation: Happiness Score
#
# Min correlation: Health (Life Expectancy)

# %% [markdown]
# ### Descriptive statistics

# %% [markdown]
# ### Describing Datasets:

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('Variables summary')
plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# ### Outcome of describe of datasets:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [raw]
# From the above code we can have the columns datatype and memory used by the dataframe.

# %% [markdown]
# ### Outliers Checking:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=['Standard Error','Economy (GDP per Capita)','Family','Health (Life Expectancy)',
         'Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']
ncol=3
nrows=5
plt.figure(figsize=(20,20))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='orange')
plt.tight_layout()

# %% [markdown]
# ### Skewness

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# ### Normal Distribution Curve:

# %%
sns.distplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(df['Happiness Rank'])
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.distplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# ### Data Cleaning:

# %%
df.corr()['Happiness Score']
# Out:
# Happiness Rank                  -0.992105
# Happiness Score                  1.000000
# Standard Error                  -0.177254
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Dystopia Residual                0.530474
# Name: Happiness Score, dtype: float64

# %%
delete=pd.DataFrame([['1.000000','Region','No','Alot'],['1.000000','Country','No','Alot']],
                   columns=['Correlation with Target','Column Name','Normalised','Outliers'])
delete
# Out:
#   Correlation with Target Column Name Normalised Outliers
# 0                1.000000      Region         No     Alot
# 1                1.000000     Country         No     Alot

# %%
df=df.drop(['Region','Country'],axis=1)

# %%
df
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %% [markdown]
# #### Removing outliers:

# %% [raw]
# IQR proximity rule

# %% [raw]
# Z-Score Technique:

# %%
from scipy.stats import zscore

# %%
np.abs(zscore(df))
# Out:
# array([[1.72099989, 1.93736005, 0.80592569, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [1.69907456, 1.91458063, 0.05588945, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [1.67714922, 1.88479215, 0.8544869 , ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [1.67742676, 2.0761992 , 0.13253425, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [1.69935209, 2.1646885 , 2.26396166, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [1.72127743, 2.22251319, 1.13418227, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
zscore(df)
# Out:
# array([[-1.72099989,  1.93736005, -0.80592569, ...,  2.30965159,
#          0.47103971,  0.75825809],
#        [-1.69907456,  1.91458063,  0.05588945, ..., -0.01647953,
#          1.57585637,  1.09285682],
#        [-1.67714922,  1.88479215, -0.8544869 , ...,  2.8427738 ,
#          0.8242928 ,  0.71233526],
#        ...,
#        [ 1.67742676, -2.0761992 ,  0.13253425, ...,  0.38141902,
#          1.85689094, -3.20843049],
#        [ 1.69935209, -2.1646885 ,  2.26396166, ..., -0.35771452,
#         -0.31694987, -0.48198451],
#        [ 1.72127743, -2.22251319,  1.13418227, ..., -0.30180313,
#         -0.5581534 , -0.96361241]])

# %%
(np.abs(zscore(df))<0).sum()
# Out:
# 0

# %%
np.abs(zscore(df))<0
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (158, 10)

# %%
type(z)
# Out:
# numpy.ndarray

# %%
z
# Out:
# array([[1.72099989, 1.93736005, 0.80592569, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [1.69907456, 1.91458063, 0.05588945, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [1.67714922, 1.88479215, 0.8544869 , ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [1.67742676, 2.0761992 , 0.13253425, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [1.69935209, 2.1646885 , 2.26396166, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [1.72127743, 2.22251319, 1.13418227, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
# if np.abs is not applied
# threshold = (-3,3)


#
# if applied np.abs
threshold=3
#index number
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
df.iloc[100]
# Out:
# Happiness Rank                   101.00000
# Happiness Score                    4.86700
# Standard Error                     0.08742
# Economy (GDP per Capita)           0.71206
# Family                             1.07284
# Health (Life Expectancy)           0.07566
# Freedom                            0.30658
# Trust (Government Corruption)      0.03060
# Generosity                         0.18259
# Dystopia Residual                  2.48676
# Name: 100, dtype: float64

# %%
len(np.where(z>3)[0])
# Out:
# 9

# %%
df_new=df[(z<3).all(axis=1)]
print('Old Dataframe',df.shape)
print('New Dataframe',df_new.shape)
print('total_dropped_rows', df.shape[0] - df_new.shape[0])
# Out:
# Old Dataframe (158, 10)
# New Dataframe (149, 10)
# total_dropped_rows 9

# %% [markdown]
# ### Percentage data loss:

# %%
loss_percent=(158-154)/158*100
print(loss_percent,'%')
# Out:
# 2.5316455696202533 %

# %% [raw]
# Model without outliers is df and model with desired outliers is df_new1:

# %% [raw]
# Dividing data in features and vectors:

# %%
df_new
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 150             151            3.655         0.05141
# 151             152            3.587         0.04324
# 152             153            3.575         0.03084
# 154             155            3.340         0.03656
# 156             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
# independent column
x=df_new.iloc[:,:-1]

# %%
#target
y=df_new.iloc[:,-1]

# %% [markdown]
# ### Transforming data to remove skewness:

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-2.05151352,  1.82591163, -0.95033703, ...,  1.75498234,
#          1.81762514,  0.65957855],
#        [-1.99584442,  1.80625026,  0.37856182, ...,  1.44218195,
#          0.32967608,  1.56260401],
#        [-1.94524081,  1.7804847 , -1.04140135, ...,  1.6160368 ,
#          1.95339957,  0.97722591],
#        ...,
#        [ 1.53128908, -1.78998689, -1.32081011, ..., -1.26539516,
#         -0.19284339,  1.13425805],
#        [ 1.56626337, -2.05390645, -0.69272644, ...,  0.31812329,
#         -0.4344978 , -0.31207994],
#        [ 1.60111233, -2.56623507,  2.17876604, ..., -1.84989335,
#         -0.14727363, -0.17248608]])

# %% [raw]
#  Since the outcome has only two variable we will use binary classification model.

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %%
x=df.drop('Happiness Score',axis=1)
y=df['Happiness Score']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.33,random_state=7)
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
models=[KNeighborsRegressor(),SVR(),DecisionTreeRegressor(),LinearRegression(),Ridge(),Lasso(),
        RandomForestRegressor()]
maelist=[]
mselist=[]
rmselist=[]
r2list=[]

# %%
def create_model(model):
    m=model
    m.fit(xtrain,ytrain)
    p=m.predict(xtest)
    
    mae=mean_absolute_error(p,ytest)
    mse=mean_squared_error(p,ytest)
    rmse=np.sqrt(mean_squared_error(p,ytest))
    r2=r2_score(ytest,p)
    
    maelist.append(mae)
    mselist.append(mse)
    rmselist.append(rmse)
    r2list.append(r2)
    
    print(m)
    print('Mean absolute error',mae)
    print('Mean squared error',mse)
    print('Root Mean squared error',rmse)
    print('R2 Score',r2)
    print('---------------------------------------------------------------------------------------------------------')
for i in models:
    create_model(i)
# Out:
# KNeighborsRegressor()
# Mean absolute error 0.03668679245283021
# Mean squared error 0.00520196981132076
# Root Mean squared error 0.07212468240013789
# R2 Score 0.995656688950707
# ---------------------------------------------------------------------------------------------------------
# SVR()
# Mean absolute error 0.08107962589856664
# Mean squared error 0.017778227202303334
# Root Mean squared error 0.1333350186646529
# R2 Score 0.9851563208851071
# ---------------------------------------------------------------------------------------------------------
# DecisionTreeRegressor()
# Mean absolute error 0.07562264150943399
# Mean squared error 0.01092916981132075
# Root Mean squared error 0.10454266981152122
# R2 Score 0.9908748443910987
# ---------------------------------------------------------------------------------------------------------
# LinearRegression()
# Mean absolute error 0.0002744672364250959
# Mean squared error 1.0640837979333214e-07
# ...
