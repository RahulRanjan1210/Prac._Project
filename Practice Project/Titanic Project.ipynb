# %% [markdown]
# ### Importing the Dataset

# %%
#importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
#reading and loading dataset
data=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.head (10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %%
data.shape
# Out:
# (891, 12)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Checking Null values in the dataframe

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
np.nan, None
# Out:
# (nan, None)

# %%
data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 866

# %%
sns.heatmap(data.isnull(),annot=True)
plt.title('Null values')
plt.show()

# %%
data.style.highlight_null(null_color='pink')
# Out:
# <style  type="text/css" >
# #T_e74a1_row0_col10,#T_e74a1_row2_col10,#T_e74a1_row4_col10,#T_e74a1_row5_col5,#T_e74a1_row5_col10,#T_e74a1_row7_col10,#T_e74a1_row8_col10,#T_e74a1_row9_col10,#T_e74a1_row12_col10,#T_e74a1_row13_col10,#T_e74a1_row14_col10,#T_e74a1_row15_col10,#T_e74a1_row16_col10,#T_e74a1_row17_col5,#T_e74a1_row17_col10,#T_e74a1_row18_col10,#T_e74a1_row19_col5,#T_e74a1_row19_col10,#T_e74a1_row20_col10,#T_e74a1_row22_col10,#T_e74a1_row24_col10,#T_e74a1_row25_col10,#T_e74a1_row26_col5,#T_e74a1_row26_col10,#T_e74a1_row28_col5,#T_e74a1_row28_col10,#T_e74a1_row29_col5,#T_e74a1_row29_col10,#T_e74a1_row30_col10,#T_e74a1_row31_col5,#T_e74a1_row32_col5,#T_e74a1_row32_col10,#T_e74a1_row33_col10,#T_e74a1_row34_col10,#T_e74a1_row35_col10,#T_e74a1_row36_col5,#T_e74a1_row36_col10,#T_e74a1_row37_col10,#T_e74a1_row38_col10,#T_e74a1_row39_col10,#T_e74a1_row40_col10,#T_e74a1_row41_col10,#T_e74a1_row42_col5,#T_e74a1_row42_col10,#T_e74a1_row43_col10,#T_e74a1_row44_col10,#T_e74a1_row45_col5,#T_e74a1_row45_col10,#T_e74a1_row46_col5,#T_e74a1_row46_col10,#T_e74a1_row47_col5,#T_e74a1_row47_col10,#T_e74a1_row48_col5,#T_e74a1_row48_col10,#T_e74a1_row49_col10,#T_e74a1_row50_col10,#T_e74a1_row51_col10,#T_e74a1_row53_col10,#T_e74a1_row55_col5,#T_e74a1_row56_col10,#T_e74a1_row57_col10,#T_e74a1_row58_col10,#T_e74a1_row59_col10,#T_e74a1_row60_col10,#T_e74a1_row61_col11,#T_e74a1_row63_col10,#T_e74a1_row64_col5,#T_e74a1_row64_col10,#T_e74a1_row65_col5,#T_e74a1_row65_col10,#T_e74a1_row67_col10,#T_e74a1_row68_col10,#T_e74a1_row69_col10,#T_e74a1_row70_col10,#T_e74a1_row71_col10,#T_e74a1_row72_col10,#T_e74a1_row73_col10,#T_e74a1_row74_col10,#T_e74a1_row76_col5,#T_e74a1_row76_col10,#T_e74a1_row77_col5,#T_e74a1_row77_col10,#T_e74a1_row78_col10,#T_e74a1_row79_col10,#T_e74a1_row80_col10,#T_e74a1_row81_col10,#T_e74a1_row82_col5,#T_e74a1_row82_col10,#T_e74a1_row83_col10,#T_e74a1_row84_col10,#T_e74a1_row85_col10,#T_e74a1_row86_col10,#T_e74a1_row87_col5,#T_e74a1_row87_col10,#T_e74a1_row89_col10,#T_e74a1_row90_col10,#T_e74a1_row91_col10,#T_e74a1_row93_col10,#T_e74a1_row94_col10,#T_e74a1_row95_col5,#T_e74a1_row95_col10,#T_e74a1_row98_col10,#T_e74a1_row99_col10,#T_e74a1_row100_col10,#T_e74a1_row101_col5,#T_e74a1_row101_col10,#T_e74a1_row103_col10,#T_e74a1_row104_col10,#T_e74a1_row105_col10,#T_e74a1_row106_col10,#T_e74a1_row107_col5,#T_e74a1_row107_col10,#T_e74a1_row108_col10,#T_e74a1_row109_col5,#T_e74a1_row109_col10,#T_e74a1_row111_col10,#T_e74a1_row112_col10,#T_e74a1_row113_col10,#T_e74a1_row114_col10,#T_e74a1_row115_col10,#T_e74a1_row116_col10,#T_e74a1_row117_col10,#T_e74a1_row119_col10,#T_e74a1_row120_col10,#T_e74a1_row121_col5,#T_e74a1_row121_col10,#T_e74a1_row122_col10,#T_e74a1_row125_col10,#T_e74a1_row126_col5,#T_e74a1_row126_col10,#T_e74a1_row127_col10,#T_e74a1_row128_col5,#T_e74a1_row129_col10,#T_e74a1_row130_col10,#T_e74a1_row131_col10,#T_e74a1_row132_col10,#T_e74a1_row133_col10,#T_e74a1_row134_col10,#T_e74a1_row135_col10,#T_e74a1_row138_col10,#T_e74a1_row140_col5,#T_e74a1_row140_col10,#T_e74a1_row141_col10,#T_e74a1_row142_col10,#T_e74a1_row143_col10,#T_e74a1_row144_col10,#T_e74a1_row145_col10,#T_e74a1_row146_col10,#T_e74a1_row147_col10,#T_e74a1_row149_col10,#T_e74a1_row150_col10,#T_e74a1_row152_col10,#T_e74a1_row153_col10,#T_e74a1_row154_col5,#T_e74a1_row154_col10,#T_e74a1_row155_col10,#T_e74a1_row156_col10,#T_e74a1_row157_col10,#T_e74a1_row158_col5,#T_e74a1_row158_col10,#T_e74a1_row159_col5,#T_e74a1_row159_col10,#T_e74a1_row160_col10,#T_e74a1_row161_col10,#T_e74a1_row162_col10,#T_e74a1_row163_col10,#T_e74a1_row164_col10,#T_e74a1_row165_col10,#T_e74a1_row166_col5,#T_e74a1_row167_col10,#T_e74a1_row168_col5,#T_e74a1_row168_col10,#T_e74a1_row169_col10,#T_e74a1_row171_col10,#T_e74a1_row172_col10,#T_e74a1_row173_col10,#T_e74a1_row175_col10,#T_e74a1_row176_col5,#T_e74a1_row176_col10,#T_e74a1_row178_col10,#T_e74a1_row179_col10,#T_e74a1_row180_col5,#T_e74a1_row180_col10,#T_e74a1_row181_col5,#T_e74a1_row181_col10,#T_e74a1_row182_col10,#T_e74a1_row184_col10,#T_e74a1_row185_col5,#T_e74a1_row1 ...

# %%
# Checking unqiue class in Pclass.
data['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
data['Age']=data['Age'].astype(float)

# %%
data.Age.dtype
# Out:
# dtype('float64')

# %%
np.mean(data['Age'])
# Out:
# 29.69911764705882

# %%
# Removing NaN from column Age column
data['Age'] = data['Age'].fillna(value=data['Age'].mean())

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Checking count of Male and female in sex column.
data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# Checking data discription.
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             89
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
#  Passenger column is Pessanger id.
#  Survivied column only have 2 values 0 and 1, this is our target variable.
#  In Pclass column we have 3 values 1,2, & 3. this are the classes for passenger.
#  In age column we have already check for null values due to which count is less.
#  Parach column shows count of perents/childern aboard the ship.
#  Mean and std difference is looking fine.
#  Quartiles differnce is also ok.

# %% [markdown]
# ### EDA

# %%
sns.pairplot(data,hue='Sex',size =3)
plt.tight_layout()

# %%
# Let's check Male, Infant, Female in our data set.
plt.pie(data['Sex'].value_counts(),labels=['Male','Female'],autopct='%.1f')
# Out:
# ([<matplotlib.patches.Wedge at 0x219ad9f82b0>,
#   <matplotlib.patches.Wedge at 0x219ad9f8ee0>],
#  [Text(-0.4919454136803954, 0.9838646807152012, 'Male'),
#   Text(0.4919455057964525, -0.9838646346559433, 'Female')],
#  [Text(-0.2683338620074884, 0.5366534622082915, '64.8'),
#   Text(0.26833391225261044, -0.53665343708506, '35.2')])

# %%
# Checking data distribution for each columns.
plt.figure(figsize=(20,15),facecolor='white')
count = 1
for column in data:
    if count <=9:
        ax = plt.subplot(3,3,count)
        sns.histplot(data[column], color='g')
        plt.xlabel(column,fontsize = 20)
    count+=1
plt.tight_layout()

# %%
from pandas.plotting import scatter_matrix
# Kde = Kernel density estimation (its kind of a graph)
scatter_matrix(data, figsize=(15,15),diagonal = 'kde',color ='c')
plt.show()

# %%
# Ploting count plot to check whether passenger servived or not.
sns.countplot('Survived',data=data)
print('Died (0)  =>',data.Survived.value_counts()[0])
print('Survived (1) =>',data.Survived.value_counts()[1])
# Out:
# Died (0)  => 549
# Survived (1) => 342

# %% [markdown]
# 549 passengers are died and 342 passengers.

# %%
sns.factorplot('Pclass', data=data, kind="count", hue='Sex')

# %% [markdown]
# Pclass 3 has more number of male as compare to female

# %%
sns.catplot(x='Sex', col='Survived', kind='count', data=data)

# %%
sns.catplot(x='Pclass',y='Survived',hue='Sex',data=data,kind='point')
print('Number of passengers in each class: \n',data.groupby(['Pclass']).size())
print('\nNumber of Female and Male in each class: \n',data.groupby(['Sex','Pclass']).size())
# Out:
# Number of passengers in each class:
#  Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64
#
# Number of Female and Male in each class:
#  Sex     Pclass
# female  1          94
#         2          76
#         3         144
# male    1         122
#         2         108
#         3         347
# dtype: int64

# %%
sns.countplot(x='Survived',data=data,hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='SibSp',data=data)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
# Let's do the same for class by changing the hue argument:

fig = sns.FacetGrid(data, hue='Pclass', aspect=4)

fig.map(sns.kdeplot, 'Age',shade=True)

oldest = data['Age'].max()

fig.set(xlim= (0,oldest))

fig.add_legend()

# %%
data.plot(kind='line', x='Sex',y='Age')
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
data.plot(kind='box', x='Sex',y='Age')
# Out:
# <AxesSubplot:>

# %%
data.plot(kind='bar', x='Sex',y='Pclass')
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
data.plot(kind='line', x='Cabin',y='Fare' , color='y')
# Out:
# <AxesSubplot:xlabel='Cabin'>

# %%
plt.figure(figsize=(5,5))
sns.stripplot(x=data['Survived'],y=data['Fare'],hue=data['Pclass'])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %% [markdown]
# P1 class passengers survive count is more then rest of classes.

# %%
sns.lmplot('Parch','Survived',data=data, hue='Sex',palette='plasma')

# %%
# Now see relationship of all the variables with target variable.
plt.figure(figsize=(20,25),facecolor='White')
plotnumber = 1
for column in data:
    if plotnumber<=11:
        ax = plt.subplot(4,3,plotnumber)
        sns.stripplot(data['Pclass'],data[column])
    plotnumber+=1
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Importing Label encoder to convert Sex column in numeric.
from sklearn.preprocessing import LabelEncoder
l_encoder = LabelEncoder()
df = l_encoder.fit_transform(data['Sex'])
data['Sex'] = df

# %% [markdown]
# From above code we have converted Sex string value to numeric where 1 means Male and 0 means Female.

# %%
data_corr = data.corr().abs()
plt.figure(figsize=(10,10))
sns.heatmap(data_corr,vmin=-1,vmax=1,annot=True,square=True,center=0, linewidths=0.1)
plt.tight_layout()

# %% [raw]
# We can see There is very less relationship between Parch and Sibsp and age.
# Plcass and Sex shows some relationship
# Passenager details does not show any relationship we can drop it.
# Fare also shows some relationship

# %% [markdown]
# ### Outliers

# %%
df = data.copy()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
cols = ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int32
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int32(1), int64(5), object(4)
# memory usage: 80.2+ KB

# %%
# Let's plot Boxplot to check outliers in our dataset.
plt.figure(figsize= (15,10))
count =1
for x in cols:
    if count <=8:
        ax = plt.subplot(2,4,count)
        data[x].plot(kind = 'box',color ='b')
    count +=1
plt.tight_layout()

# %% [markdown]
# ### Droping unwanted columns

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.drop(columns=['PassengerId','Ticket','Cabin','Embarked','Name'], axis=1, inplace= True)

# %%
# Let's check our data set now.
data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0         0       3    1  22.0      1      0   7.2500
# 1         1       1    0  38.0      1      0  71.2833
# 2         1       3    0  26.0      0      0   7.9250
# 3         1       1    0  35.0      1      0  53.1000
# 4         0       3    1  35.0      0      0   8.0500

# %%
# Ploting Box plot for checking outliers.
plt.figure(figsize= (20,25))
count =1
for column in data:
    if count <=7:
        ax = plt.subplot(2,4,count)
        data[column].plot(kind = 'box',color ='b')
    count +=1
plt.tight_layout()

# %% [markdown]
# ### Removing Skewness and Outliers

# %%
# Let's first deal with Outliers.
from scipy.stats import zscore
z =np.abs(zscore(data))
df = data[(z<3).all(axis = 1)]

# %%
print('Data size before z_score: ',data.shape,' Data size after z_score: ',df.shape)
# Out:
# Data size before z_score:  (891, 7)  Data size after z_score:  (820, 7)

# %%
data_loss = ((891 - 820)/891)*100
print('Data loss after applying Z_score: ',data_loss)
# Out:
# Data loss after applying Z_score:  7.968574635241302

# %%
#Let's check skewness again for new data frame.
df.skew()
# Out:
# Survived    0.450825
# Pclass     -0.632242
# Sex        -0.664152
# Age         0.318314
# SibSp       1.979577
# Parch       2.122629
# Fare        2.318761
# dtype: float64

# %% [markdown]
# ### Seperating Independant variables and Target variable

# %%
# Seperating Features and Label.
x = df.drop(['Survived'],axis=1)
y = df['Survived']

# %%
x.skew()
# Out:
# Pclass   -0.632242
# Sex      -0.664152
# Age       0.318314
# SibSp     1.979577
# Parch     2.122629
# Fare      2.318761
# dtype: float64

# %% [markdown]
# ### Transforming data to remove skewness:

# %%
 # let's remove the skewness 
from sklearn.preprocessing import power_transform
df_new = power_transform(x)
df_new  = pd.DataFrame(df_new,columns=x.columns)
df_new.head()
# Out:
#      Pclass       Sex       Age     SibSp     Parch      Fare
# 0  0.872830  0.722036 -0.618468  1.551886 -0.484693 -0.834702
# 1 -1.470676 -1.384973  0.685884  1.551886 -0.484693  1.553645
# 2  0.872830 -1.384973 -0.283814 -0.633505 -0.484693 -0.743314
# 3 -1.470676 -1.384973  0.447557  1.551886 -0.484693  1.250341
# 4  0.872830  0.722036  0.447557 -0.633505 -0.484693 -0.727191

# %%
df_new.skew()
# Out:
# Pclass   -0.429718
# Sex      -0.664152
# Age       0.071813
# SibSp     0.948944
# Parch     1.581505
# Fare     -0.018602
# dtype: float64

# %%
# Let's check distribution again.
plt.figure(figsize=(30,25), facecolor='white')
plotnumber = 1

for column in df_new:
    if plotnumber <= 12:
        ax = plt.subplot(4,3,plotnumber)
        sns.distplot(df_new[column])
        plt.xlabel(column,fontsize=25)
        
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# As we can see from above values skewness is removed from all the columns. Now data distribution looks like normally distributed.

# %%
x = df_new ## Lets store this Dataframe back to x.

# %% [markdown]
# ### Class Imbalancing

# %%
# Now let's deal with Class imbalance problem.
from imblearn.over_sampling import SMOTE
sm = SMOTE()
x_new,y_new = sm.fit_resample(x,y)

# %%
y_new.shape
# Out:
# (1000,)

# %%
x_new.shape
# Out:
# (1000, 6)

# %% [markdown]
# ### Scaling (Standardization)

# %%
# Now lets scale our data.
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
x_new = scale.fit_transform(x_new)

# %%
x_new.shape
# Out:
# (1000, 6)

# %%
# Now converting data into Train test split.
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_new,y_new,test_size=0.25,random_state=43)

# %%
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (750, 6) (750,) (250, 6) (250,)

# %% [markdown]
# ### Splitting the dataframe:

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print('At random state',i,'The model performs very well')
        print('At random_state:-',i)
        print('Training accuracy_score is:-',accuracy_score(y_train,pred_train)*100)
        print('Testing accuracy_score is:-', accuracy_score(y_test,pred_test)*100)
# Out:
# At random state 169 The model performs very well
# At random_state:- 169
# Training accuracy_score is:- 79.8780487804878
# Testing accuracy_score is:- 79.8780487804878
# At random state 286 The model performs very well
# At random_state:- 286
# Training accuracy_score is:- 79.8780487804878
# Testing accuracy_score is:- 79.8780487804878
# At random state 324 The model performs very well
# At random_state:- 324
# Training accuracy_score is:- 79.26829268292683
# Testing accuracy_score is:- 79.26829268292683
# At random state 505 The model performs very well
# At random_state:- 505
# Training accuracy_score is:- 80.48780487804879
# Testing accuracy_score is:- 80.48780487804879
# At random state 580 The model performs very well
# At random_state:- 580
# Training accuracy_score is:- 79.26829268292683
# Testing accuracy_score is:- 79.26829268292683
# At random state 603 The model performs very well
# At random_state:- 603
# Training accuracy_score is:- 79.8780487804878
# Testing accuracy_score is:- 79.8780487804878
# At random state 618 The model performs very well
# At random_state:- 618
# Training accuracy_score is:- 79.8780487804878
# Testing accuracy_score is:- 79.8780487804878
# At random state 679 The model performs very well
# At random_state:- 679
# Training accuracy_score is:- 79.26829268292683
# Testing accuracy_score is:- 79.26829268292683
# At random state 687 The model performs very well
# At random_state:- 687
# Training accuracy_score is:- 79.8780487804878
# Testing accuracy_score is:- 79.8780487804878
# At random state 698 The model performs very well
# At random_state:- 698
# Training accuracy_score is:- 79.26829268292683
# Testing accuracy_score is:- 79.26829268292683
# At random state 717 The model performs very well
# At random_state:- 717
# Training accuracy_score is:- 79.26829268292683
# Testing accuracy_score is:- 79.26829268292683
# At random state 780 The model performs very well
# At random_state:- 780
# Training accuracy_score is:- 79.26829268292683
# Testing accuracy_score is:- 79.26829268292683
# At random state 861 The model performs very well
# At random_state:- 861
# Training accuracy_score is:- 79.8780487804878
# Testing accuracy_score is:- 79.8780487804878
# At random state 900 The model performs very well
# At random_state:- 900
# Training accuracy_score is:- 79.8780487804878
# Testing accuracy_score is:- 79.8780487804878
# At random state 920 The model performs very well
# At random_state:- 920
# Training accuracy_score is:- 79.8780487804878
# Testing accuracy_score is:- 79.8780487804878
# At random state 947 The model performs very well
# At random_state:- 947
# Training accuracy_score is:- 79.26829268292683
# Testing accuracy_score is:- 79.26829268292683

# %% [markdown]
# ### Finding best model

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score, roc_curve, plot_roc_curve

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.33,random_state=7)
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
models=[KNeighborsRegressor(),SVR(),DecisionTreeRegressor(),LinearRegression(),Ridge(),Lasso(),
        RandomForestRegressor()]
maelist=[]
mselist=[]
rmselist=[]
r2list=[]

# %%
def create_model(model):
    m=model
    m.fit(xtrain,ytrain)
    p=m.predict(xtest)
    
    mae=mean_absolute_error(p,ytest)
    mse=mean_squared_error(p,ytest)
    rmse=np.sqrt(mean_squared_error(p,ytest))
    r2=r2_score(ytest,p)
    
    maelist.append(mae)
    mselist.append(mse)
    rmselist.append(rmse)
    r2list.append(r2)
    
    print(m)
    print('Mean absolute error',mae)
    print('Mean squared error',mse)
    print('Root Mean squared error',rmse)
    print('R2 Score',r2)
    print('---------------------------------------------------------------------------------------------------------')
for i in models:
    create_model(i)
# Out:
# KNeighborsRegressor()
# Mean absolute error 0.24723247232472326
# Mean squared error 0.14332103321033213
# Root Mean squared error 0.37857764488983253
# R2 Score 0.41459176863181313
# ---------------------------------------------------------------------------------------------------------
# SVR()
# Mean absolute error 0.2449802684277006
# Mean squared error 0.15796372227131317
# Root Mean squared error 0.3974465024016606
# R2 Score 0.35478232884719085
# ---------------------------------------------------------------------------------------------------------
# DecisionTreeRegressor()
# Mean absolute error 0.23785362853628533
# Mean squared error 0.229044946699467
# Root Mean squared error 0.47858640463292207
# R2 Score 0.06444438650970219
# ---------------------------------------------------------------------------------------------------------
# LinearRegression()
# Mean absolute error 0.296568654625743
# Mean squared error 0.1535309108881415
# Root Mean squared error 0.3918302067071163
# R2 Score 0.3728885635964405
# ---------------------------------------------------------------------------------------------------------
# Ridge()
# Mean absolute error 0.29681413391692013
# Mean squared error 0.1535204766837456
# Root Mean squared error 0.3918168917794964
# R2 Score 0.37293118308504114
# ---------------------------------------------------------------------------------------------------------
# Lasso()
# Mean absolute error 0.48151956929405376
# Mean squared error 0.24801005870848827
# Root Mean squared error 0.49800608300349936
# R2 Score -0.013020396085099195
# ---------------------------------------------------------------------------------------------------------
# RandomForestRegressor()
# Mean absolute error 0.2328320503809434
# Mean squared error 0.14157726796793862
# Root Mean squared error 0.37626754838537246
# R2 Score 0.4217143416666641
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Hyper parameter tuning using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'n_estimators':np.arange(100,150,10),
          'criterion':['gini','entropy'],
          'max_depth':[11],
          'min_samples_split':np.arange(2,10,2),
          'min_samples_leaf': np.arange(5,20,5),
          'max_features':['auto','sqrt','log2']}

# %%
print(params)
# Out:
# {'n_estimators': array([100, 110, 120, 130, 140]), 'criterion': ['gini', 'entropy'], 'max_depth': [11], 'min_samples_split': array([2, 4, 6, 8]), 'min_samples_leaf': array([ 5, 10, 15]), 'max_features': ['auto', 'sqrt', 'log2']}

# %%
gridsearch = GridSearchCV(estimator= RandomForestClassifier(),param_grid=params,cv=5,n_jobs=-1)

# %%
gridsearch.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [11],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': array([ 5, 10, 15]),
#                          'min_samples_split': array([2, 4, 6, 8]),
#                          'n_estimators': array([100, 110, 120, 130, 140])})

# %%
gridsearch.best_params_  # This are the best parameter we have to use for this model
# Out:
# {'criterion': 'gini',
#  'max_depth': 11,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 5,
#  'min_samples_split': 8,
#  'n_estimators': 110}

# %%
# Instantiating Random Forest Classifier again using best parameters.
rfc = RandomForestClassifier(n_estimators=170,criterion='entropy',max_depth=11,max_features='log2',min_samples_split=4,random_state=36)

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=11, max_features='log2',
#                        min_samples_split=4, n_estimators=170, random_state=36)

# %%
y_rfc_pred = rfc.predict(x_test)

# %%
confusion_matrix(y_test,y_rfc_pred)
# Out:
# array([[95, 11],
#        [15, 43]], dtype=int64)

# %%
acc = classification_report(y_test,y_rfc_pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88       106
#            1       0.80      0.74      0.77        58
#
#     accuracy                           0.84       164
#    macro avg       0.83      0.82      0.82       164
# weighted avg       0.84      0.84      0.84       164

# %%
cross_val_score(rfc,x_new,y_new,cv=5).mean()
# Out:
# 0.8309999999999998

# %% [markdown]
# ### Let's PLOT roc_auc curve for our model

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(pred_test, y_test)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=10, label='ROC curve(area = %0.2f)'% roc_auc)
plt.plot([0, 1],[0, 1],color='navy',lw=10,linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0,1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Model Saving:

# %%
import pickle
Survival = 'Titanic.pickle'
pickle.dump(lr,open(Survival,'wb'))
